# %%
import pandas as pd
dbs = pd.read_csv("I:\DataAnalytics\Python9-project\countryData.csv")
dbc= pd.read_csv("I:\DataAnalytics\Python9-project\immunitizationData.csv")

# %%
dbs.describe(include ='all')
# Out:
#        Country         Year      Status  Life expectancy   Adult Mortality  \
# count     2938  2938.000000        2938       2928.000000      2928.000000
# unique     193          NaN           2               NaN              NaN
# top     Brazil          NaN  Developing               NaN              NaN
# freq        16          NaN        2426               NaN              NaN
# mean       NaN  2007.518720         NaN         69.224932       164.796448
# std        NaN     4.613841         NaN          9.523867       124.292079
# min        NaN  2000.000000         NaN         36.300000         1.000000
# 25%        NaN  2004.000000         NaN         63.100000        74.000000
# 50%        NaN  2008.000000         NaN         72.100000       144.000000
# 75%        NaN  2012.000000         NaN         75.700000       228.000000
# max        NaN  2015.000000         NaN         89.000000       723.000000
#
# ...

# %%
dbc.describe(include='all')
# Out:
#        Country         Year  infant deaths  Hepatitis B       Measles   \
# count     2938  2938.000000    2938.000000  2385.000000    2938.000000
# unique     193          NaN            NaN          NaN            NaN
# top      Niger          NaN            NaN          NaN            NaN
# freq        16          NaN            NaN          NaN            NaN
# mean       NaN  2007.518720      30.303948    80.940461    2419.592240
# std        NaN     4.613841     117.926501    25.070016   11467.272489
# min        NaN  2000.000000       0.000000     1.000000       0.000000
# 25%        NaN  2004.000000       0.000000    77.000000       0.000000
# 50%        NaN  2008.000000       3.000000    92.000000      17.000000
# 75%        NaN  2012.000000      22.000000    97.000000     360.250000
# max        NaN  2015.000000    1800.000000    99.000000  212183.000000
#
#                BMI   under-five deaths         Polio  Diphtheria      HIV/AIDS
# ...

# %%
dbs.head
# Out:
# <bound method NDFrame.head of           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       Alcohol  Total expenditure         GDP  Population  \
# ...

# %%
dbs.describe(all)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b9f387cb2fd6> in <module>
# ----> 1 dbs.describe(all)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in describe(self, percentiles, include, exclude, datetime_is_numeric)
#   10277         if percentiles is not None:
#   10278             # explicit conversion of `percentiles` to list
# > 10279             percentiles = list(percentiles)
#   10280
#   10281             # get them all to be in [0, 1]
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
print(dbs.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'Alcohol', 'Total expenditure', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
print(dbc.columns)
# Out:
# Index(['Country', 'Year', 'infant deaths', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Diphtheria ', ' HIV/AIDS'],
#       dtype='object')

# %%
dbs.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# Alcohol                            194
# Total expenditure                  226
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
dbc.isna().sum()
# Out:
# Country                 0
# Year                    0
# infant deaths           0
# Hepatitis B           553
# Measles                 0
#  BMI                   34
# under-five deaths       0
# Polio                  19
# Diphtheria             19
#  HIV/AIDS               0
# dtype: int64

# %%
print(dbs.duplicated().sum())
# Out:
# 0

# %%
print(dbc.duplicated().sum())
# Out:
# 0

# %%
dbs["UniqueKey"] = dbs.apply(lambda x : x['Country'] + str(x['Year']), axis=1)
dbc["UniqueKey"] = dbc.apply(lambda x : x['Country'] + str(x['Year']), axis=1)

# %%
dbs
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       Alcohol  Total expenditure         GDP  Population  \
# ...

# %%
dbc
# Out:
#           Country  Year  infant deaths  Hepatitis B  Measles    BMI   \
# 0     Afghanistan  2015             62         65.0      1154   19.1
# 1     Afghanistan  2014             64         62.0       492   18.6
# 2     Afghanistan  2013             66         64.0       430   18.1
# 3     Afghanistan  2012             69         67.0      2787   17.6
# 4     Afghanistan  2011             71         68.0      3013   17.2
# ...           ...   ...            ...          ...       ...    ...
# 2933     Zimbabwe  2004             27         68.0        31   27.1
# 2934     Zimbabwe  2003             26          7.0       998   26.7
# 2935     Zimbabwe  2002             25         73.0       304   26.3
# 2936     Zimbabwe  2001             25         76.0       529   25.9
# 2937     Zimbabwe  2000             24         79.0      1483   25.5
#
#       under-five deaths   Polio  Diphtheria    HIV/AIDS        UniqueKey
# ...

# %%
dft = pd.merge(dbs, dbc, on = 'UniqueKey', how = 'inner')
print(dft.shape)
# Out:
# (2938, 24)

# %%
dft
# Out:
#         Country_x  Year_x      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan    2015  Developing              65.0            263.0
# 1     Afghanistan    2014  Developing              59.9            271.0
# 2     Afghanistan    2013  Developing              59.9            268.0
# 3     Afghanistan    2012  Developing              59.5            272.0
# 4     Afghanistan    2011  Developing              59.2            275.0
# ...           ...     ...         ...               ...              ...
# 2933     Zimbabwe    2004  Developing              44.3            723.0
# 2934     Zimbabwe    2003  Developing              44.5            715.0
# 2935     Zimbabwe    2002  Developing              44.8             73.0
# 2936     Zimbabwe    2001  Developing              45.3            686.0
# 2937     Zimbabwe    2000  Developing              46.0            665.0
#
#       Alcohol  Total expenditure         GDP  Population  \
# ...

# %%
dft.rename(columns=lambda x: x.strip(),inplace=True)

# %%
print(dft['Income composition of resources'])
# Out:
# 0       0.479
# 1       0.476
# 2       0.470
# 3       0.463
# 4       0.454
#         ...
# 2933    0.407
# 2934    0.418
# 2935    0.427
# 2936    0.427
# 2937    0.434
# Name: Income composition of resources, Length: 2938, dtype: float64

# %%
dft.columns
# Out:
# Index(['Country_x', 'Year_x', 'Status', 'Life expectancy', 'Adult Mortality',
#        'Alcohol', 'Total expenditure', 'GDP', 'Population',
#        'thinness  1-19 years', 'thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'UniqueKey',
#        'Country_y', 'Year_y', 'infant deaths', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Diphtheria', 'HIV/AIDS'],
#       dtype='object')

# %%
for v in ["Life expectancy", "Adult Mortality", "Alcohol", "Total expenditure", "GDP", "Population", "thinness  1-19 years","thinness 5-9 years", "Income composition of resources", "Schooling", "Hepatitis B", "BMI", "Polio", "Diphtheria"]: 
    dft[v].fillna(dft[v].median(), inplace=True)

# %%
 dft["Life expectancy "].fillna(dft["Life expectancy "].median(), inplace=True)

# %%
dft.isna().sum()
# Out:
# Country_x                          0
# Year_x                             0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# Alcohol                            0
# Total expenditure                  0
# GDP                                0
# Population                         0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# UniqueKey                          0
# Country_y                          0
# Year_y                             0
# infant deaths                      0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Diphtheria                         0
# HIV/AIDS                           0
# dtype: int64

# %%
x = '     thanikaivel   '

# %%
x.strip(' a')
# Out:
# 'thanikaivel'

# %%
x
# Out:
# '     thanikaivel   '

# %%
x.strip()
# Out:
# 'thanikaivel'

# %%
dft.columns=dft.columns.strip(' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-e842e638dbce> in <module>
# ----> 1 dft.columns=dft.columns.strip(' ')
#
# AttributeError: 'Index' object has no attribute 'strip'

# %%
for v in ["Life expectancy ", "Adult Mortality", "Alcohol", "Total expenditure", "GDP", "Population", " thinness  1-19 years"," thinness 5-9 years", "Income composition of resources", "Schooling", "Hepatitis B", " BMI ", "Polio", "Diphtheria "]: 
    dft[v]=dft[v].strip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-9adde12883bf> in <module>
#       1 for v in ["Life expectancy ", "Adult Mortality", "Alcohol", "Total expenditure", "GDP", "Population", " thinness  1-19 years"," thinness 5-9 years", "Income composition of resources", "Schooling", "Hepatitis B", " BMI ", "Polio", "Diphtheria "]:
# ----> 2     dft[v]=dft[v].strip()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
dft.rename(columns=lambda x: x.strip(),inplace=True)

# %%
dft.columns
# Out:
# Index(['Country_x', 'Year_x', 'Status', 'Life expectancy', 'Adult Mortality',
#        'Alcohol', 'Total expenditure', 'GDP', 'Population',
#        'thinness  1-19 years', 'thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'UniqueKey',
#        'Country_y', 'Year_y', 'infant deaths', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Diphtheria', 'HIV/AIDS'],
#       dtype='object')

# %%
from matplotlib import pyplot as plt 
from matplotlib import pyplot as plt1

# %%
import seaborn as sns

# %%
sns.pairplot(dft)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6006f12d52c9> in <module>
# ----> 1 sns.pairplot(dft)
#
# NameError: name 'sns' is not defined

# %%
fig = plt.figure(figsize =(18, 20))
plt.subplot(4,4,1)
x,y,_=plt.hist(dft['Life expectancy'])
plt.title('Life expectany')
plt.xlabel('year')
plt.ylabel('count')
print(x)
print(y)
plt.subplot(4,4,2)
x1,y1,_=plt.hist(dft['Adult Mortality'])
plt.title('Adult Mortality')
plt.xlabel('samples')
plt.ylabel('count')
print(x1)
print(y1)
plt.subplot(4,4,3)
x2,y2,_=plt.hist(dft['Alcohol'])
plt.title('Alcohol')
plt.xlabel('Alcohol level')
plt.ylabel('count')
print(x2)
print(y2)
plt.subplot(4,4,4)
x3,y3,_=plt.hist(dft['Total expenditure'])
plt.title('Total expenditure')
plt.xlabel('Expenditure level')
plt.ylabel('count')
print(x3)
print(y3)
plt.subplot(4,4,5)
plt.hist(dft['GDP'])
plt.title('GDP')
plt.xlabel('GDP in USD')
plt.ylabel('count')
plt.subplot(4,4,6)
plt.hist(dft['thinness  1-19 years'])
plt.title('thinness  1-19 years')
plt.xlabel('Prevalence level')
plt.ylabel('count')
plt.subplot(4,4,7)
plt.hist(dft['thinness 5-9 years'])
plt.title('thinness 5-9 years')
plt.xlabel('Prevalence level')
plt.ylabel('count')
plt.subplot(4,4,8)
plt.hist(dft['Income composition of resources'])
plt.title('Income composition of resources')
plt.xlabel('Index range')
plt.ylabel('count')
plt.subplot(4,4,9)
plt.hist(dft['infant deaths'])
plt.title('infant deaths')
plt.xlabel('Percentage')
plt.ylabel('count')
plt.subplot(4,4,10)
plt.hist(dft['Hepatitis B'])
plt.title('Hepatitis B')
plt.xlabel('Percentage')
plt.ylabel('count')
plt.subplot(4,4,11)
plt.hist(dft['Measles'])
plt.title('Measles')
plt.xlabel('Percentage')
plt.ylabel('count')
plt.subplot(4,4,12)
plt.hist(dft['BMI'])
plt.title('BMI')
plt.xlabel('Index')
plt.ylabel('count')
plt.subplot(4,4,13)
plt.hist(dft['under-five deaths'])
plt.title('under-five deaths')
plt.xlabel('Percentage')
plt.ylabel('count')
plt.subplot(4,4,14)
plt.hist(dft['Polio'])
plt.title('Polio')
plt.xlabel('Percentage')
plt.ylabel('count')
plt.subplot(4,4,15)
plt.hist(dft['Diphtheria'])
plt.title('Diphtheria')
plt.xlabel('Percentage')
plt.ylabel('count')
plt.subplot(4,4,16)
plt.hist(dft['HIV/AIDS'])
plt.title('HIV/AIDS')
plt.xlabel('Percentage')
plt.ylabel('count')
plt.savefig('I://DataAnalytics/Python9-project/univariate1.pdf')
# Out:
# [  4.  50. 134. 229. 277. 405. 590. 819. 362.  68.]
# [36.3  41.57 46.84 52.11 57.38 62.65 67.92 73.19 78.46 83.73 89.  ]
# [729. 775. 610. 423. 176. 117.  54.  24.  17.  13.]
# [  1.   73.2 145.4 217.6 289.8 362.  434.2 506.4 578.6 650.8 723. ]
# [969. 375. 521. 289. 263. 242. 198.  66.  10.   5.]
# [1.0000e-02 1.7960e+00 3.5820e+00 5.3680e+00 7.1540e+00 8.9400e+00
#  1.0726e+01 1.2512e+01 1.4298e+01 1.6084e+01 1.7870e+01]
# [150. 384. 708. 949. 460. 184.  71.  16.   7.   9.]
# [ 0.37   2.093  3.816  5.539  7.262  8.985 10.708 12.431 14.154 15.877
#  17.6  ]

# %%
y, x,_ =plt.hist(dft['Total expenditure'])

# %%
fig = plt.figure(figsize =(15, 7))
plt.subplot(2,2,1)
plt.scatter(dft['thinness  1-19 years'],dft['Life expectancy'])
plt.xlabel('thinness  1-19 years')
plt.ylabel('Life expectancy')
plt.subplot(2,2,2)
plt.scatter(dft['Measles'],dft['Life expectancy'])
plt.xlabel('Measles')
plt.ylabel('Life expectancy')
plt.subplot(2,2,3)
plt.scatter(dft['HIV/AIDS'],dft['Life expectancy'])
plt.xlabel('HIV/AIDS')
plt.ylabel('Life expectancy')
plt.subplot(2,2,4)
plt.scatter(dft['BMI'],dft['Life expectancy'])
plt.xlabel('BMI')
plt.ylabel('Life expectancy')
plt.savefig('I://DataAnalytics/Python9-project/Bivariate1.pdf')

# %%
fig = plt.figure(figsize =(17, 5))
plt.subplot(1,3,1)
plt.scatter(dft['Hepatitis B'],dft['Life expectancy'])
plt.xlabel('Hepatitis B')
plt.ylabel('Life expectancy')
plt.subplot(1,3,2)
plt.scatter(dft['Polio'],dft['Life expectancy'])
plt.xlabel('Polio')
plt.ylabel('Life expectancy')
plt.subplot(1,3,3)
plt.scatter(dft['Diphtheria'],dft['Life expectancy'])
plt.xlabel('Diphtheria')
plt.ylabel('Life expectancy')
plt.savefig('I://DataAnalytics/Python9-project/Bivariate2.pdf')

# %%
fig = plt.figure(figsize =(17, 5))
plt.subplot(1,2,1)
plt.scatter(dft['Adult Mortality'],dft['Life expectancy'])
plt.xlabel('Adult Mortality')
plt.ylabel('Life expectancy')
plt.subplot(1,2,2)
plt.scatter(dft['infant deaths'],dft['Life expectancy'])
plt.xlabel('infant deaths')
plt.ylabel('Life expectancy')
plt.savefig('I://DataAnalytics/Python9-project/Bivariate3.pdf')

# %%
fig = plt.figure(figsize =(17, 5))
plt.subplot(1,2,1)
plt.scatter(dft['GDP'],dft['Life expectancy'])
plt.xlabel('GDP')
plt.ylabel('Life expectancy')
plt.subplot(1,2,2)
plt.scatter(dft['Schooling'],dft['Life expectancy'])
plt.xlabel('Schooling')
plt.ylabel('Life expectancy')
plt.savefig('I://DataAnalytics/Python9-project/Bivariate4.pdf')

# %%
dft.columns
# Out:
# Index(['Country_x', 'Year_x', 'Status', 'Life expectancy', 'Adult Mortality',
#        'Alcohol', 'Total expenditure', 'GDP', 'Population',
#        'thinness  1-19 years', 'thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'UniqueKey',
#        'Country_y', 'Year_y', 'infant deaths', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Diphtheria', 'HIV/AIDS'],
#       dtype='object')

# %%
print(x.max())
print(y.max())
# Out:
# 17.6
# 949.0

# %%
plt.hist(dft['Life expectancy'])
# Out:
# (array([  4.,  50., 134., 229., 277., 405., 590., 819., 362.,  68.]),
#  array([36.3 , 41.57, 46.84, 52.11, 57.38, 62.65, 67.92, 73.19, 78.46,
#         83.73, 89.  ]),
#  <BarContainer object of 10 artists>)

# %%
dft.groupby(by=["Country_x"]).mean().sort_values(by=["Life expectancy"], ascending=False)["Life expectancy"]
# Out:
# Country_x
# Japan                       82.53750
# Sweden                      82.51875
# Iceland                     82.44375
# Switzerland                 82.33125
# France                      82.21875
#                               ...
# Malawi                      49.89375
# Angola                      49.01875
# Lesotho                     48.78125
# Central African Republic    48.51250
# Sierra Leone                46.11250
# Name: Life expectancy, Length: 193, dtype: float64

# %%
dft.loc[([dft["Life expectancy"].rank(method ='average')][dft["Country_x"]=='India'])
# Out:
#   File "<ipython-input-129-73b492d04c4e>", line 1
#     dft.loc[([dft["Life expectancy"].rank(method ='average')][dft["Country_x"]=='India'])
#                                                                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
dft["Life expectancy"].rank(method ='average')
# Out:
# 0       858.0
# 1       586.0
# 2       586.0
# 3       557.0
# 4       534.0
#         ...
# 2933     11.5
# 2934     13.5
# 2935     18.5
# 2936     23.0
# 2937     39.0
# Name: Life expectancy, Length: 2938, dtype: float64

# %%
dft.groupby(dft["Country_x"])

# %%
axe=plt.subplots(1,1)
axe=plt.hist(dft['Total expenditure'],bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-39d7d93f4448> in <module>
# ----> 1 axe=plt.subplots(1,1)
#       2 axe.hist(dft['Total expenditure'],bins=20)
#
# AttributeError: module 'matplotlib' has no attribute 'subplots'

# %%
dft
# Out:
#         Country_x  Year_x      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan    2015  Developing             65.0            263.0
# 1     Afghanistan    2014  Developing             59.9            271.0
# 2     Afghanistan    2013  Developing             59.9            268.0
# 3     Afghanistan    2012  Developing             59.5            272.0
# 4     Afghanistan    2011  Developing             59.2            275.0
# ...           ...     ...         ...              ...              ...
# 2933     Zimbabwe    2004  Developing             44.3            723.0
# 2934     Zimbabwe    2003  Developing             44.5            715.0
# 2935     Zimbabwe    2002  Developing             44.8             73.0
# 2936     Zimbabwe    2001  Developing             45.3            686.0
# 2937     Zimbabwe    2000  Developing             46.0            665.0
#
#       Alcohol  Total expenditure         GDP  Population  \
# ...

# %%
dft.query("Country_x=='India'")
# Out:
#      Country_x  Year_x      Status  Life expectancy  Adult Mortality  Alcohol  \
# 1186     India    2015  Developing             68.3            181.0    3.755
# 1187     India    2014  Developing             68.0            184.0    3.070
# 1188     India    2013  Developing             67.6            187.0    3.110
# 1189     India    2012  Developing             67.3             19.0    3.100
# 1190     India    2011  Developing             66.8            193.0    3.000
# 1191     India    2010  Developing             66.4            196.0    2.770
# 1192     India    2009  Developing             66.0              2.0    2.500
# 1193     India    2008  Developing             65.5             23.0    1.930
# 1194     India    2007  Developing             65.2             26.0    1.590
# 1195     India    2006  Developing             64.8             28.0    1.370
# 1196     India    2005  Developing             64.4            211.0    1.270
# ...

# %%
sns.pairplot(dft)

# %%
sns.show()
